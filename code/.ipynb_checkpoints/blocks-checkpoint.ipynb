# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import terminalLogic
from terminalLogic import Algo
import client
from client import engine
from typing import Optional, Dict, Any, List
from ciso8601 import parse_datetime
from requests import Request, Session, Response
import requests
import sys
import hmac
import urllib.parse
import time
from time import sleep
import plotly.graph_objects as go
from ta import add_all_ta_features
from ta.utils import dropna
from datetime import datetime
import schedule
import logging
from apscheduler.schedulers.background import BackgroundScheduler
plt.rcParams["figure.figsize"] = (100,10)

# %%
def runall():
    data = engine()
    df = data.ignition()
    e = Algo.dataReader(df)
    f = Algo.marketStateSelector(e[0], e[1])
    g = Algo.phaseChanger(df, f[0])
    return g
time.sleep(2)
a=runall()
a
# take ML course 
# take HTML course
# zscore polling validation
# connect z score decision maker to ML and optomise
# create constantly updating db for portfolio and for each algo or a joined algo db with all trades, and historical
# create and order manager
# create additional ftx sub account on new offshore acct
# look at all VPS providers
# Out:
# Range detector algo's ZScore indicates there is a 'Ranging' market state.. ..Z Score: -10.673551423362381
# Here is the range_df with our range indicator suite
# All trades for the next period will be placed according to the conditions within...
#                     time     open     high      low    close       volume  \
# 0    2021-09-29 01:11:00  41703.0  41718.0  41664.0  41718.0  155693.3905
# 1    2021-09-29 01:12:00  41718.0  41754.0  41700.0  41737.0  342643.9425
# 2    2021-09-29 01:13:00  41737.0  41781.0  41732.0  41734.0  356516.3988
# 3    2021-09-29 01:14:00  41733.0  41797.0  41720.0  41778.0  279982.7603
# 4    2021-09-29 01:15:00  41778.0  41790.0  41701.0  41759.0  322176.0132
# ...                  ...      ...      ...      ...      ...          ...
# 1495 2021-09-30 02:06:00  42969.0  43022.0  42969.0  43015.0   96828.0626
# 1496 2021-09-30 02:07:00  43015.0  43024.0  42983.0  43007.0  237438.0391
# ...

# %%
# Out:
#                     time     open     high      low    close        volume  \
# 0    2021-09-29 00:47:00  41572.0  41572.0  41494.0  41501.0  4.996591e+05
# 1    2021-09-29 00:48:00  41501.0  41525.0  41473.0  41473.0  1.813185e+05
# 2    2021-09-29 00:49:00  41473.0  41521.0  41398.0  41399.0  2.407591e+06
# 3    2021-09-29 00:50:00  41399.0  41444.0  41399.0  41436.0  2.142499e+05
# 4    2021-09-29 00:51:00  41436.0  41500.0  41421.0  41449.0  4.551208e+06
# ...                  ...      ...      ...      ...      ...           ...
# 1495 2021-09-30 01:42:00  42859.0  42862.0  42841.0  42859.0  5.834498e+04
# 1496 2021-09-30 01:43:00  42859.0  42859.0  42819.0  42819.0  1.819275e+05
# 1497 2021-09-30 01:44:00  42819.0  42819.0  42787.0  42798.0  2.107543e+05
# 1498 2021-09-30 01:45:00  42798.0  42836.0  42798.0  42835.0  1.026474e+05
# 1499 2021-09-30 01:46:00  42835.0  42840.0  42833.0  42835.0  8.378802e+03
#
#                 ma     ratio  position  returnsR  strat_returnR
# ...

# %%
# while True:
#   btc_one_min =  f'https://ftx.com/api/markets/BTC/USD/candles?resolution=60'
#   r = requests.get(btc_one_min)
#   minute = pd.json_normalize(r.json()['result'])
#   time.sleep(5)

# %%
# import os
# from apscheduler.schedulers.blocking import BlockingScheduler
# data = engine()
# df = data.ignition()
# e = Algo.dataReader(df)
# f = Algo.marketStateSelector(e[0], e[1])
# g = Algo.phaseChanger(df, f[0])
# def tick():
#     print('Tick! The time is: %s' % datetime.now())
# def data():
#     print('dataGrabber! The time is: %s' % datetime.now())
#     data=engine()
#     return data
# def _df():
#     df = data.ignition()
#     return df
# def _e():
#     e = Algo.dataReader(df)
#     return e
# def _f():
#     f = Algo.marketStateSelector(e[0], e[1])
#     return f
# def _g():
#     g = Algo.phaseChanger(df, f[0])
#     return g
# if __name__ == '__main__':
#     scheduler = BlockingScheduler()
#     scheduler.add_executor('processpool')
#     scheduler.add_job(tick, 'interval', seconds=10)
#     scheduler.add_job(data, 'interval', seconds=13)
#     scheduler.add_job(_df, 'interval', seconds=16)
#     scheduler.add_job(_e, 'interval', seconds=19)
#     scheduler.add_job(_f, 'interval', seconds=12)
#     scheduler.add_job(_g, 'interval', seconds=15)
#     print('Press Ctrl+{0} to exit'.format('Break' if os.name == 'nt' else 'C'))

#     try:
#         scheduler.start()
#     except (KeyboardInterrupt, SystemExit):
#         pass

# %%
# def runall():
#     data=engine()
#     df = data.ignition()
#     e = Algo.dataReader(df)
#     f = Algo.marketStateSelector(e[0], e[1])
# #     g = Algo.phaseChanger(df, f[0])
#     return f

# a=runall()
# a

# %%
# data=engine()
# df = data.ignition()
# e = Algo.dataReader(df)
# f = Algo.marketStateSelector(e[0], e[1])
# g = Algo.phaseChanger(df, f[0])
# def data():
#     print('dataGrabber! The time is: %s' % datetime.now())
#     data=engine()
#     return data
# def _df():
#     df = data.ignition()
#     return df
# def _e(df):
#     e = Algo.dataReader(df)
#     return e
# def _f(_e):
#     f = Algo.marketStateSelector(e[0], e[1])
#     return f
# def _g(_f):
#     g = Algo.phaseChanger(df, f[0])
#     return g
# if __name__ == '__main__':
#     scheduler = BackgroundScheduler()
#     scheduler.add_job(data, 'interval', seconds=10)
#     scheduler.add_job(_df, 'interval', seconds=11)
#     scheduler.add_job(_e, 'interval', seconds=12)
#     scheduler.add_job(_f, 'interval', seconds=13)
#     scheduler.add_job(_g, 'interval', seconds=14)
#     scheduler.start()
#     try:
#         data=engine()
#         df = data.ignition()
#         e = Algo.dataReader(df)
#         f = Algo.marketStateSelector(e[0], e[1])
#         g = Algo.phaseChanger(df, f[0])
#         while True:
#             g
#             time.sleep(10)
#     except (KeyboardInterrupt, SystemExit):
#         # Not strictly necessary if daemonic mode is enabled but should be done if possible
#         scheduler.shutdown()

# %%
# def runMode(): 
    
# a = runMode()
# schedule.every(10).seconds.do(runMode)
# while True:
#     data=engine()
#     df = data.ignition()
#     e = Algo.dataReader(df)
#     f = Algo.marketStateSelector(e[0], e[1])
#     g = Algo.phaseChanger(df, f[0])
#     schedule.run_pending()
    
# return g
# g
# time.sleep(10)

# %%
# schedule.every(10).seconds.do(data=engine)
# schedule.every(10).seconds.do(df = data.ignition())
# schedule.every(10).seconds.do(e = Algo.dataReader(df))
# schedule.every(10).seconds.do(f = Algo.marketStateSelector(e[0], e[1]))
# schedule.every(10).seconds.do(g = Algo.phaseChanger(df, f[0]))
# while True:
#     schedule.run_pending()
#     time.sleep(5)
