# %%
import pandas as pd
import numpy as np
import time
import requests
import matplotlib.pyplot as plt
import terminalLogic
from terminalLogic import Algo
import client
from client import FtxClient
import psycopg2
import psycopg2.extras as extras
from sqlalchemy import create_engine
from config import user, password, host, database, param_dic
from typing import Optional, Dict, Any, List
from ciso8601 import parse_datetime
from requests import Request, Session, Response
import sys
import hmac
import urllib.parse
import time
import plotly.graph_objects as go
from datetime import datetime
plt.rcParams["figure.figsize"] = (100,10)

# %% [markdown]
# ## Need to set program to run api every and write new rows, backtest and print results to table

# %%
# btc = FtxClient()
# btc_df = btc.get_all_markets('BTC-PERP')

# %% [markdown]
# ## Need to get data to and from sql

# %%
# db=pd.json_normalize(btc_df)

# db.to_csv('data/btc1m.csv')

# %%
df = pd.read_csv('data/btc1m.csv')

# %%
df
# Out:
#          Unnamed: 0                  startTime          time      open  \
# 0                 0  2021-09-24T14:50:00+00:00  1.632495e+12  42496.00
# 1                 1  2021-09-24T14:51:00+00:00  1.632495e+12  42499.00
# 2                 2  2021-09-24T14:52:00+00:00  1.632495e+12  42448.00
# 3                 3  2021-09-24T14:53:00+00:00  1.632495e+12  42489.00
# 4                 4  2021-09-24T14:54:00+00:00  1.632495e+12  42495.00
# ...             ...                        ...           ...       ...
# 1149634     1149634  2019-07-20T17:51:00+00:00  1.563645e+12  10911.50
# 1149635     1149635  2019-07-20T17:52:00+00:00  1.563645e+12  10924.50
# 1149636     1149636  2019-07-20T17:53:00+00:00  1.563645e+12  10931.75
# 1149637     1149637  2019-07-20T17:54:00+00:00  1.563645e+12  10920.00
# 1149638     1149638  2019-07-20T12:35:00+00:00  1.563626e+12  10564.25
#
#              high       low     close        volume
# 0        42504.00  42483.00  42499.00  1.698576e+06
# 1        42500.00  42441.00  42448.00  4.811636e+06
# 2        42511.00  42434.00  42489.00  6.554035e+06
# 3        42551.00  42486.00  42495.00  1.571488e+06
# 4        42506.00  42379.00  42397.00  3.966496e+06
# ...           ...       ...       ...           ...
# 1149634  10924.50  10911.50  10924.50  0.000000e+00
# 1149635  10931.75  10916.75  10931.75  0.000000e+00
# 1149636  10931.75  10917.00  10920.00  0.000000e+00
# 1149637  10927.25  10920.00  10926.50  0.000000e+00
# 1149638  10572.25  10560.50  10567.75  6.365293e+05
#
# [1149639 rows x 8 columns]

# %%
ma = 30
# calc rate ofreturn close to close
df['returns'] = np.log(df["close"]).diff()
# add column to keep track of mean or moving average
df['ma'] = df['close'].rolling(ma).mean()
# to decide when too far away from mean add column called ratio
df['ratio'] = df['close'] / df['ma']
# create variable for price points that might work
percentiles = [5, 10, 50, 90, 95]
# get a look at where percentiles are w numpy percential function on btc ratio column
np.percentile(df['ratio'].dropna(), percentiles)
p = np.percentile(df['ratio'].dropna(), percentiles)

# %%
# Define place where we short at 95th percentile and long at 5th
short = p[-1]
long = p[0]
# use np.where which is numpys version of excels 'if' function
# add column to df for position value
# look at ratio column -1 indicates short otherwise nan
df['position'] = np.where(df.ratio > short, -1, np.nan)
# when long position at 1 instead of np.nan we leave btc['position'] where it is.
df['position'] = np.where(df.ratio < long, 1, df['position'])
# This strat isnt neutral, its always in a long or short.
df['position'] = df['position'].ffill()
df['strat_return'] = df['returns'] * df['position'].shift()

# %%
# visual look at ratio column
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

df['ratio'].head(1500).dropna().plot(legend = True)
plt.axhline(p[0], c= (.5,.5,.5), ls='--')
plt.axhline(p[2], c= (.5,.5,.5), ls='--')
plt.axhline(p[-1], c= (.5,.5,.5), ls='--');
# can see ratio move around mean

# %%
# df.position.dropna().plot()
plt.plot(df.head(2500).position.dropna())
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
plt.plot(np.exp(df['returns'].head(2500).dropna()).cumprod(), label='Buy/Hold')
plt.plot(np.exp(df['strat_return'].head(2500).dropna()).cumprod(), label='Strategy')
plt.xticks(rotation=90)
plt.legend();

# %%
# final value for each column
print("Returns over time period specified within api call: ")
print(np.exp(df['returns'].dropna()).cumprod().iloc[-2])
print(np.exp(df['strat_return'].dropna()).cumprod().iloc[-2])
# Out:
# Returns over time period specified within api call:
# 0.2571001670628389
# 11712.382150417656

# %%
_max = df['close'].max()
_max
_min = df['close'].min()
_diff = _max - _min
_last = df['close'].iloc[0]
_last - _max
# Out:
# -22564.0

# %%
df['profit'] = df['close'].diff()
profit = df['profit'].sum()

df['algo_profit'] = df['profit'] * df['position'].shift()
algo = df['algo_profit'].sum()
print("market: ", profit, "Algo: ", algo)
# Out:
# market:  -358.75 Algo:  358.75

# %%
df = df.drop(df.columns[0], axis = 1)

# %%
df = df.drop("startTime", axis=1)

# %%
df1 = df

# %%
df['goodTrades'] = np.where((df.strat_return / df.close) * .15 > df.returns / df.close, 1, np.nan)
df['goodTrades'] = np.where((df.strat_return / df.close)* .15 < df.returns / df.close, 0, df['goodTrades'])
df = df.drop("time", axis=1)
df
# Out:
#              open      high       low     close        volume   returns  \
# 0        42496.00  42504.00  42483.00  42499.00  1.698576e+06       NaN
# 1        42499.00  42500.00  42441.00  42448.00  4.811636e+06 -0.001201
# 2        42448.00  42511.00  42434.00  42489.00  6.554035e+06  0.000965
# 3        42489.00  42551.00  42486.00  42495.00  1.571488e+06  0.000141
# 4        42495.00  42506.00  42379.00  42397.00  3.966496e+06 -0.002309
# ...           ...       ...       ...       ...           ...       ...
# 1149634  10911.50  10924.50  10911.50  10924.50  0.000000e+00  0.001191
# 1149635  10924.50  10931.75  10916.75  10931.75  0.000000e+00  0.000663
# 1149636  10931.75  10931.75  10917.00  10920.00  0.000000e+00 -0.001075
# 1149637  10920.00  10927.25  10920.00  10926.50  0.000000e+00  0.000595
# 1149638  10564.25  10572.25  10560.50  10567.75  6.365293e+05 -0.033384
#
#                    ma     ratio  position  strat_return  goodTrades
# 0                 NaN       NaN       NaN           NaN         NaN
# 1                 NaN       NaN       NaN           NaN         NaN
# 2                 NaN       NaN       NaN           NaN         NaN
# 3                 NaN       NaN       NaN           NaN         NaN
# 4                 NaN       NaN       NaN           NaN         NaN
# ...               ...       ...       ...           ...         ...
# 1149634  10929.850000  0.999511      -1.0     -0.001191         0.0
# 1149635  10929.716667  1.000186      -1.0     -0.000663         0.0
# 1149636  10928.791667  0.999196      -1.0      0.001075         1.0
# 1149637  10926.741667  0.999978      -1.0     -0.000595         0.0
# 1149638  10913.350000  0.968332       1.0      0.033384         1.0
#
# [1149639 rows x 11 columns]

# %%
print(df['goodTrades'].value_counts())
# Out:
# 1.0    537673
# 0.0    534145
# Name: goodTrades, dtype: int64

# %%
ds = df.isin([np.inf, -np.inf]).value_counts()
print(ds)
# Out:
# open   high   low    close  volume  returns  ma     ratio  position  strat_return  goodTrades
# False  False  False  False  False   False    False  False  False     False         False         1149639
# dtype: int64

# %%
dNaN = df.isin([np.nan]).value_counts()
print(dNaN)
# Out:
# open   high   low    close  volume  returns  ma     ratio  position  strat_return  goodTrades
# False  False  False  False  False   False    False  False  False     False         False         1071818
#                                                                                    True            77777
#                                              True   True   True      True          True               28
#                                              False  False  True      True          True               14
#                                     True     True   True   True      True          True                1
#                                     False    False  False  False     True          True                1
# dtype: int64

# %%
df[:] = np.nan_to_num(df)

# %%
target = df["goodTrades"]
target_names = [0, 1]

# %%
data = df.drop("goodTrades", axis=1)
feature_names = data.columns
data.dropna()
# Out:
#              open      high       low     close        volume   returns  \
# 0        42496.00  42504.00  42483.00  42499.00  1.698576e+06  0.000000
# 1        42499.00  42500.00  42441.00  42448.00  4.811636e+06 -0.001201
# 2        42448.00  42511.00  42434.00  42489.00  6.554035e+06  0.000965
# 3        42489.00  42551.00  42486.00  42495.00  1.571488e+06  0.000141
# 4        42495.00  42506.00  42379.00  42397.00  3.966496e+06 -0.002309
# ...           ...       ...       ...       ...           ...       ...
# 1149634  10911.50  10924.50  10911.50  10924.50  0.000000e+00  0.001191
# 1149635  10924.50  10931.75  10916.75  10931.75  0.000000e+00  0.000663
# 1149636  10931.75  10931.75  10917.00  10920.00  0.000000e+00 -0.001075
# 1149637  10920.00  10927.25  10920.00  10926.50  0.000000e+00  0.000595
# 1149638  10564.25  10572.25  10560.50  10567.75  6.365293e+05 -0.033384
#
#                    ma     ratio  position  strat_return
# 0            0.000000  0.000000       0.0      0.000000
# 1            0.000000  0.000000       0.0      0.000000
# 2            0.000000  0.000000       0.0      0.000000
# 3            0.000000  0.000000       0.0      0.000000
# 4            0.000000  0.000000       0.0      0.000000
# ...               ...       ...       ...           ...
# 1149634  10929.850000  0.999511      -1.0     -0.001191
# 1149635  10929.716667  1.000186      -1.0     -0.000663
# 1149636  10928.791667  0.999196      -1.0      0.001075
# 1149637  10926.741667  0.999978      -1.0     -0.000595
# 1149638  10913.350000  0.968332       1.0      0.033384
#
# [1149639 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import tree

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = .4, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9999934762186423

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9999956508124282

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.8099431786041607, 'returns'),
#  (0.13859284418206524, 'position'),
#  (0.03346179834872638, 'strat_return'),
#  (0.015391958757876726, 'ratio'),
#  (0.0011669285318285471, 'volume'),
#  (0.0004119542145765506, 'ma'),
#  (0.0004013604551942298, 'open'),
#  (0.00023078370044218107, 'low'),
#  (0.0002188497773133935, 'high'),
#  (0.00018034342781594027, 'close')]

# %%
from ta import add_all_ta_features
from ta.utils import dropna

# %%
trend = Algo.trendy(df1,df1)
trend
# Out:
#                  time      open      high       low     close        volume  \
# 44       1.632498e+12  41915.00  42008.00  41888.00  41931.00  4.899315e+06
# 45       1.632498e+12  41931.00  42029.00  41927.00  42028.00  6.327074e+06
# 46       1.632498e+12  42028.00  42080.00  42012.00  42041.00  5.242025e+06
# 47       1.632498e+12  42041.00  42041.00  41980.00  42006.00  1.930239e+06
# 48       1.632498e+12  42006.00  42007.00  41943.00  41946.00  1.481499e+06
# ...               ...       ...       ...       ...       ...           ...
# 1149634  1.563645e+12  10911.50  10924.50  10911.50  10924.50  0.000000e+00
# 1149635  1.563645e+12  10924.50  10931.75  10916.75  10931.75  0.000000e+00
# 1149636  1.563645e+12  10931.75  10931.75  10917.00  10920.00  0.000000e+00
# 1149637  1.563645e+12  10920.00  10927.25  10920.00  10926.50  0.000000e+00
# 1149638  1.563626e+12  10564.25  10572.25  10560.50  10567.75  6.365293e+05
#
#           returns            ma     ratio  position  strat_return  goodTrades  \
# 44       0.000382  42225.866667  0.993017       1.0      0.000382         0.0
# 45       0.002311  42217.800000  0.995504       1.0      0.002311         0.0
# 46       0.000309  42208.700000  0.996027       1.0      0.000309         0.0
# 47      -0.000833  42200.200000  0.995398       1.0     -0.000833         1.0
# 48      -0.001429  42189.966667  0.994217       1.0     -0.001429         1.0
# ...           ...           ...       ...       ...           ...         ...
# 1149634  0.001191  10929.850000  0.999511      -1.0     -0.001191         0.0
# 1149635  0.000663  10929.716667  1.000186      -1.0     -0.000663         0.0
# 1149636 -0.001075  10928.791667  0.999196      -1.0      0.001075         1.0
# 1149637  0.000595  10926.741667  0.999978      -1.0     -0.000595         0.0
# 1149638 -0.033384  10913.350000  0.968332       1.0      0.033384         1.0
#
#                 9-min        21-min  signal  returnsT     strat  entry
# 44       42163.444444  42218.285714      -1       NaN       NaN    NaN
# 45       42132.888889  42200.809524      -1  0.002311 -0.002311    0.0
# 46       42108.888889  42189.619048      -1  0.000309 -0.000309    0.0
# 47       42081.444444  42175.000000      -1 -0.000833  0.000833    0.0
# 48       42056.666667  42160.523810      -1 -0.001429  0.001429    0.0
# ...               ...           ...     ...       ...       ...    ...
# 1149634  10902.277778  10921.583333      -1  0.001191 -0.001191    0.0
# 1149635  10905.000000  10921.047619      -1  0.000663 -0.000663    0.0
# 1149636  10909.444444  10920.535714      -1 -0.001075  0.001075    0.0
# 1149637  10912.777778  10919.773810      -1  0.000595 -0.000595    0.0
# 1149638  10915.000000  10919.869048      -1 -0.033384  0.033384    0.0
#
# [1071818 rows x 18 columns]

# %%
trend = dropna(trend)

# %%
trend = add_all_ta_features(
    trend, open="open", high="high", low="low", close="close", volume="volume")
trend
# Out:
# C:\Users\tbrid\anaconda3\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# C:\Users\tbrid\anaconda3\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#                  time      open      high       low     close        volume  \
# 65       1.632499e+12  41799.00  41799.00  41710.00  41739.00  3.841313e+06
# 124      1.632502e+12  42202.00  42205.00  42174.00  42183.00  8.669042e+05
# 130      1.632503e+12  42213.00  42213.00  42125.00  42127.00  1.832847e+06
# 150      1.632504e+12  42181.00  42181.00  42141.00  42154.00  5.723326e+05
# 162      1.632505e+12  41877.00  41911.00  41753.00  41790.00  5.918801e+06
# ...               ...       ...       ...       ...       ...           ...
# 1149199  1.563728e+12  10370.00  10374.75  10363.00  10363.00  3.390360e+04
# 1149217  1.563729e+12  10429.00  10430.75  10411.25  10420.25  1.745064e+03
# 1149234  1.563730e+12  10389.75  10389.75  10378.75  10388.25  6.669257e+02
# 1149519  1.563638e+12  10629.25  10629.50  10622.25  10623.00  9.441754e+05
# 1149536  1.563639e+12  10674.75  10700.00  10638.75  10638.75  4.334620e+04
#
#           returns            ma     ratio  position  ...  momentum_wr  \
# 65      -0.001436  41941.133333  0.995181       1.0  ...          NaN
# 124     -0.000450  42207.633333  0.999416      -1.0  ...          NaN
# 130     -0.002039  42212.433333  0.997976      -1.0  ...          NaN
# 150     -0.000640  42106.233333  1.001134      -1.0  ...          NaN
# 162     -0.002080  42055.833333  0.993679       1.0  ...          NaN
# ...           ...           ...       ...       ...  ...          ...
# 1149199 -0.000916  10387.458333  0.997645      -1.0  ...   -78.827913
# 1149217 -0.000839  10374.108333  1.004448      -1.0  ...   -71.070461
# 1149234 -0.000144  10383.508333  1.000457      -1.0  ...   -75.406504
# 1149519 -0.000776  10615.483333  1.000708      -1.0  ...   -43.597561
# 1149536 -0.002933  10627.441667  1.001064      -1.0  ...   -50.957535
#
#          momentum_ao  momentum_kama  momentum_roc  momentum_ppo  \
# 65               NaN            NaN           NaN           NaN
# 124              NaN            NaN           NaN           NaN
# 130              NaN            NaN           NaN           NaN
# 150              NaN            NaN           NaN           NaN
# 162              NaN            NaN           NaN           NaN
# ...              ...            ...           ...           ...
# 1149199   313.810294   10315.290070      1.277823    -20.925766
# 1149217   271.316912   10316.181041      1.964382    -27.656918
# 1149234   225.172794   10328.040761      1.763280    -33.854439
# 1149519   238.992647   10329.288072      2.620330      0.931269
# 1149536   263.970588   10333.775032     -2.635733     -6.211580
#
#          momentum_ppo_signal  momentum_ppo_hist  others_dr  others_dlr  \
# 65                       NaN                NaN  78.115938         NaN
# 124                      NaN                NaN   1.063753    1.058135
# 130                      NaN                NaN  -0.132755   -0.132843
# 150                      NaN                NaN   0.064092    0.064071
# 162                      NaN                NaN  -0.863500   -0.867250
# ...                      ...                ...        ...         ...
# 1149199             3.173715         -24.099481  -0.501668   -0.502931
# 1149217            -2.992412         -24.664506   0.552446    0.550926
# 1149234            -9.164817         -24.689621  -0.307094   -0.307567
# 1149519            -7.145600           8.076869   2.259765    2.234610
# 1149536            -6.958796           0.747216   0.148263    0.148153
#
#          others_cr
# 65        0.000000
# 124       1.063753
# 130       0.929586
# 150       0.994274
# 162       0.122188
# ...            ...
# 1149199 -75.171902
# 1149217 -75.034740
# 1149234 -75.111407
# 1149519 -74.548983
# 1149536 -74.511248
#
# [28612 rows x 101 columns]

# %%
for col in trend.columns:
    print(col)
# Out:
# time
# open
# high
# low
# close
# volume
# returns
# ma
# ratio
# position
# strat_return
# goodTrades
# 9-min
# 21-min
# signal
# returnsT
# strat
# entry
# volume_adi
# volume_obv
# volume_cmf
# volume_fi
# volume_mfi
# volume_em
# volume_sma_em
# volume_vpt
# volume_nvi
# volume_vwap
# volatility_atr
# volatility_bbm
# volatility_bbh
# volatility_bbl
# volatility_bbw
# volatility_bbp
# volatility_bbhi
# volatility_bbli
# volatility_kcc
# volatility_kch
# volatility_kcl
# volatility_kcw
# volatility_kcp
# volatility_kchi
# volatility_kcli
# volatility_dcl
# volatility_dch
# volatility_dcm
# volatility_dcw
# volatility_dcp
# volatility_ui
# trend_macd
# trend_macd_signal
# trend_macd_diff
# trend_sma_fast
# trend_sma_slow
# trend_ema_fast
# trend_ema_slow
# trend_adx
# trend_adx_pos
# trend_adx_neg
# trend_vortex_ind_pos
# trend_vortex_ind_neg
# trend_vortex_ind_diff
# trend_trix
# trend_mass_index
# trend_cci
# trend_dpo
# trend_kst
# trend_kst_sig
# trend_kst_diff
# trend_ichimoku_conv
# trend_ichimoku_base
# trend_ichimoku_a
# trend_ichimoku_b
# trend_visual_ichimoku_a
# trend_visual_ichimoku_b
# trend_aroon_up
# trend_aroon_down
# trend_aroon_ind
# trend_psar_up
# trend_psar_down
# trend_psar_up_indicator
# trend_psar_down_indicator
# trend_stc
# momentum_rsi
# momentum_stoch_rsi
# momentum_stoch_rsi_k
# momentum_stoch_rsi_d
# momentum_tsi
# momentum_uo
# momentum_stoch
# momentum_stoch_signal
# momentum_wr
# momentum_ao
# momentum_kama
# momentum_roc
# momentum_ppo
# momentum_ppo_signal
# momentum_ppo_hist
# others_dr
# others_dlr
# others_cr

# %%
trend['goodTrades'] = np.where(trend.strat_return > trend.returnsT, 1, np.nan)
trend['goodTrades'] = np.where(trend.strat_return < trend.returnsT, 0, trend['goodTrades'])
trend[:] = np.nan_to_num(trend)
trend
# Out:
#                  time      open      high       low     close        volume  \
# 65       1.632499e+12  41799.00  41799.00  41710.00  41739.00  3.841313e+06
# 124      1.632502e+12  42202.00  42205.00  42174.00  42183.00  8.669042e+05
# 130      1.632503e+12  42213.00  42213.00  42125.00  42127.00  1.832847e+06
# 150      1.632504e+12  42181.00  42181.00  42141.00  42154.00  5.723326e+05
# 162      1.632505e+12  41877.00  41911.00  41753.00  41790.00  5.918801e+06
# ...               ...       ...       ...       ...       ...           ...
# 1149199  1.563728e+12  10370.00  10374.75  10363.00  10363.00  3.390360e+04
# 1149217  1.563729e+12  10429.00  10430.75  10411.25  10420.25  1.745064e+03
# 1149234  1.563730e+12  10389.75  10389.75  10378.75  10388.25  6.669257e+02
# 1149519  1.563638e+12  10629.25  10629.50  10622.25  10623.00  9.441754e+05
# 1149536  1.563639e+12  10674.75  10700.00  10638.75  10638.75  4.334620e+04
#
#           returns            ma     ratio  position  ...  momentum_wr  \
# 65      -0.001436  41941.133333  0.995181       1.0  ...     0.000000
# 124     -0.000450  42207.633333  0.999416      -1.0  ...     0.000000
# 130     -0.002039  42212.433333  0.997976      -1.0  ...     0.000000
# 150     -0.000640  42106.233333  1.001134      -1.0  ...     0.000000
# 162     -0.002080  42055.833333  0.993679       1.0  ...     0.000000
# ...           ...           ...       ...       ...  ...          ...
# 1149199 -0.000916  10387.458333  0.997645      -1.0  ...   -78.827913
# 1149217 -0.000839  10374.108333  1.004448      -1.0  ...   -71.070461
# 1149234 -0.000144  10383.508333  1.000457      -1.0  ...   -75.406504
# 1149519 -0.000776  10615.483333  1.000708      -1.0  ...   -43.597561
# 1149536 -0.002933  10627.441667  1.001064      -1.0  ...   -50.957535
#
#          momentum_ao  momentum_kama  momentum_roc  momentum_ppo  \
# 65          0.000000       0.000000      0.000000      0.000000
# 124         0.000000       0.000000      0.000000      0.000000
# 130         0.000000       0.000000      0.000000      0.000000
# 150         0.000000       0.000000      0.000000      0.000000
# 162         0.000000       0.000000      0.000000      0.000000
# ...              ...            ...           ...           ...
# 1149199   313.810294   10315.290070      1.277823    -20.925766
# 1149217   271.316912   10316.181041      1.964382    -27.656918
# 1149234   225.172794   10328.040761      1.763280    -33.854439
# 1149519   238.992647   10329.288072      2.620330      0.931269
# 1149536   263.970588   10333.775032     -2.635733     -6.211580
#
#          momentum_ppo_signal  momentum_ppo_hist  others_dr  others_dlr  \
# 65                  0.000000           0.000000  78.115938    0.000000
# 124                 0.000000           0.000000   1.063753    1.058135
# 130                 0.000000           0.000000  -0.132755   -0.132843
# 150                 0.000000           0.000000   0.064092    0.064071
# 162                 0.000000           0.000000  -0.863500   -0.867250
# ...                      ...                ...        ...         ...
# 1149199             3.173715         -24.099481  -0.501668   -0.502931
# 1149217            -2.992412         -24.664506   0.552446    0.550926
# 1149234            -9.164817         -24.689621  -0.307094   -0.307567
# 1149519            -7.145600           8.076869   2.259765    2.234610
# 1149536            -6.958796           0.747216   0.148263    0.148153
#
#          others_cr
# 65        0.000000
# 124       1.063753
# 130       0.929586
# 150       0.994274
# 162       0.122188
# ...            ...
# 1149199 -75.171902
# 1149217 -75.034740
# 1149234 -75.111407
# 1149519 -74.548983
# 1149536 -74.511248
#
# [28612 rows x 101 columns]

# %%
a = plot_gainsT(trend)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-a47563f42de4> in <module>
# ----> 1 a = plot_gainsT(trend)
#       2 a
#
# NameError: name 'plot_gainsT' is not defined

# %%
target = trend["goodTrades"]
target_names = [0, 1]

# %%
data = trend.drop(["goodTrades", "returnsT", "time", "returns", "position", "strat_return", "entry", "signal", "ratio", "strat"],  axis=1)
feature_names = data.columns
data.dropna()

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree

X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier(max_depth=6)
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)

# %%
from sklearn import tree
import graphviz

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=data.columns,  
                      class_names=['0', '1'],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render("btc1m") 
graph

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
for max_depth in range (2,40):
    rf = RandomForestClassifier(n_estimators=200, max_depth=max_depth, max_leaf_nodes=100)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7505941562980568

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.07570140647371038, 'momentum_stoch_rsi'),
#  (0.07083613676039573, 'volatility_kcp'),
#  (0.0517721489044994, 'momentum_stoch'),
#  (0.05161729262426099, 'momentum_wr'),
#  (0.04643820910241264, 'others_dr'),
#  (0.0425357123857313, 'volatility_kchi'),
#  (0.04080469233526699, 'volatility_dcp'),
#  (0.03848166108465226, 'others_dlr'),
#  (0.038139617540204306, 'volume_vpt'),
#  (0.034407375947297335, 'volatility_kcli'),
#  (0.02388198446509984, 'volatility_bbp'),
#  (0.021065801962994384, 'momentum_uo'),
#  (0.020704503250629176, 'momentum_roc'),
#  (0.020436936207827185, 'trend_cci'),
#  (0.01955400981006295, 'volatility_ui'),
#  (0.018568480289522793, 'trend_adx_pos'),
#  (0.017818542308015304, 'trend_adx_neg'),
#  (0.01716376292864812, 'momentum_stoch_rsi_k'),
#  (0.017074279684987016, 'momentum_rsi'),
#  (0.01640294489694527, 'volatility_dcw'),
#  (0.014941419121351268, 'volatility_bbw'),
#  (0.01429461070381657, 'volatility_atr'),
#  (0.013989525307454466, 'volatility_kcw'),
#  (0.01021911890738036, 'momentum_stoch_signal'),
#  (0.00983724320248587, 'momentum_ao'),
#  (0.009584855587103812, 'trend_macd_diff'),
#  (0.009411990058108896, 'trend_kst_diff'),
#  (0.008495448476556436, 'trend_aroon_up'),
#  (0.008366065217326649, 'volume_em'),
#  (0.00820232633502159, 'trend_aroon_down'),
#  (0.00782002547398959, 'volume_obv'),
#  (0.007489709160588613, 'volume_nvi'),
#  (0.007304105178943917, 'trend_stc'),
#  (0.007294160781454151, 'volume_adi'),
#  (0.00680254255158273, 'trend_trix'),
#  (0.00648210446055519, 'trend_kst'),
#  (0.00647397863046108, 'trend_macd'),
#  (0.006405316555947517, 'trend_macd_signal'),
#  (0.0063379048140885215, 'momentum_tsi'),
#  (0.005404399151859887, 'volume_sma_em'),
#  (0.005331024765438307, 'volume_fi'),
#  (0.004910393332562, 'trend_kst_sig'),
#  (0.0047454015412428645, 'trend_adx'),
#  (0.0044749340813999795, 'trend_visual_ichimoku_b'),
#  (0.00437559907512715, 'trend_dpo'),
#  (0.0041918289786834735, 'trend_visual_ichimoku_a'),
#  (0.003865298615542014, 'momentum_stoch_rsi_d'),
#  (0.0037038931328329592, 'trend_ichimoku_b'),
#  (0.003691646243934955, 'trend_sma_slow'),
#  (0.003637963775535741, 'volume_cmf'),
#  (0.0033514787697268697, 'trend_ichimoku_base'),
#  (0.0032992088809962066, 'volatility_bbh'),
#  (0.0032024481714728586, 'momentum_kama'),
#  (0.0031752510189432884, 'volatility_bbl'),
#  (0.003170041511895563, 'volatility_dcl'),
#  (0.00312873553987435, 'volume_mfi'),
#  (0.0031184121818264585, 'trend_mass_index'),
#  (0.003110797143687036, 'volatility_kcc'),
#  (0.0029858777299231654, 'trend_vortex_ind_neg'),
#  (0.0029236288188081478, 'trend_psar_down'),
#  (0.00289955772777525, '21-min'),
#  (0.002858330081128757, 'volatility_dch'),
#  (0.0028111565540748884, 'trend_vortex_ind_diff'),
#  (0.0027594257564489376, 'trend_ema_fast'),
#  (0.0027532507179848136, 'trend_aroon_ind'),
#  (0.002734468371409215, 'trend_ichimoku_conv'),
#  (0.00272226126986669, 'volatility_bbm'),
#  (0.002716187298340449, 'trend_vortex_ind_pos'),
#  (0.002671771223188494, 'trend_ichimoku_a'),
#  (0.0026219517697969544, 'ma'),
#  (0.0026046787808898966, '9-min'),
#  (0.0025238899451660406, 'volatility_kch'),
#  (0.0025213702080825037, 'trend_ema_slow'),
#  (0.002490227580815604, 'volatility_kcl'),
#  (0.002453691081409732, 'volatility_dcm'),
#  (0.0023718750985967027, 'volume_vwap'),
#  (0.0023436425615977444, 'momentum_ppo_signal'),
#  (0.002274317432445272, 'close'),
#  (0.00217713449054968, 'trend_psar_up'),
#  (0.002129698495695608, 'open'),
#  (0.0020698864702695004, 'trend_sma_fast'),
#  (0.002023986138521554, 'momentum_ppo'),
#  (0.0019684583989771735, 'low'),
#  (0.0019542870191317377, 'others_cr'),
#  (0.0018783457290592381, 'high'),
#  (0.0018088532844291534, 'momentum_ppo_hist'),
#  (0.0016741367205889944, 'volume'),
#  (0.0013819006763688057, 'volatility_bbli'),
#  (0.0008196422811378744, 'volatility_bbhi'),
#  (2.540488755909419e-05, 'trend_psar_down_indicator'),
#  (0.0, 'trend_psar_up_indicator')]
