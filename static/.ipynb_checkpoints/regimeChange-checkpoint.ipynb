# %%
from pandas_datareader import data as web
import numpy as np
import pandas as pd
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV as rcv
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean') 
import matplotlib.pyplot as plt
from IPython import get_ipython
import requests
import matplotlib.pyplot as plt
import terminalLogic
from terminalLogic import Algo
import client
from client import engine
from typing import Optional, Dict, Any, List
from ciso8601 import parse_datetime
from requests import Request, Session, Response
import sys
import hmac
import urllib.parse
import time
import datetime

# %%
url = engine()
data = url.getData()
df = data
df = df[::-1]
df
# Out:
#                     time     open     high      low    close       volume
# 1499 2021-11-05 17:17:00  60900.0  60900.0  60890.0  60899.0   33845.6608
# 1498 2021-11-05 17:16:00  60899.0  60919.0  60884.0  60900.0  146219.8716
# 1497 2021-11-05 17:15:00  60934.0  60958.0  60892.0  60899.0  261698.6033
# 1496 2021-11-05 17:14:00  60930.0  60938.0  60902.0  60934.0  303779.9910
# 1495 2021-11-05 17:13:00  60968.0  60968.0  60930.0  60930.0  410266.7035
# ...                  ...      ...      ...      ...      ...          ...
# 4    2021-11-04 16:22:00  61274.0  61275.0  61236.0  61240.0  273021.6630
# 3    2021-11-04 16:21:00  61212.0  61274.0  61200.0  61274.0  401271.9601
# 2    2021-11-04 16:20:00  61275.0  61275.0  61212.0  61212.0  493137.0058
# 1    2021-11-04 16:19:00  61324.0  61342.0  61274.0  61275.0  352766.4585
# 0    2021-11-04 16:18:00  61276.0  61332.0  61249.0  61324.0  645490.4828
#
# [1500 rows x 6 columns]

# %% [markdown]
# # Creating Hyperparameters
# ## Although the concept of hyper-parameters is worthy of a blog in itself, for now I will just say a few words about them. These are the parameters that the machine learning algorithm can’t learn over but needs to be iterated over. We use them to see which predefined functions or parameters yield the best fit function.

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
steps = [('imputation', imp),
         ('scaler',StandardScaler()),
         ('lasso',Lasso())]        

pipeline =Pipeline(steps)


parameters = {'lasso__alpha':np.arange(0.0001,10,.0001),
              'lasso__max_iter':np.random.uniform(100,100000,4)}


reg = rcv(pipeline, parameters,cv=5)

# %% [markdown]
# # Splitting the data into test and train sets

# %%
X=df[['open','high','low','close']]
y =df['close']
avg_err={}

# %% [markdown]
# # Getting the best fit parameters to create a new function
#
# ## I want to measure the performance of the regression function as compared to the size of the input dataset. In other words, I want to see if by increasing the input data, will we be able to reduce the error. For this, I used for loop to iterate over the same data set but with different lengths.

# %% [markdown]
# ## Now we can start making the predictions and checking the performance
# ## Let us predict the future close values. To do this we pass on test X, containing data from split to end, to the regression function using the predict() function. We also want to see how well the function has performed, so let us save these values in a new column.

# %%
avg_err={}
avg_train_err = {}
for t in np.arange(50,97,3):
    get_ipython().magic('reset_selective -f reg1')
    split = int(t*len(X)/100)
    reg.fit(X[:split],y[:split])
    best_alpha = reg.best_params_['lasso__alpha']
    best_iter = reg.best_params_['lasso__max_iter']
    reg1 = Lasso(alpha=best_alpha,max_iter=best_iter)
    X = imp.fit_transform(X,y)
    reg1.fit(X[:split],y[:split])
    df['P_C_%i'%t] = 0.
    df.iloc[:,df.columns.get_loc('P_C_%i'%t)] = reg1.predict(X[:])
    df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
    
    e = np.mean(df['Error_%i'%t][split:])
    train_e = np.mean(df['Error_%i'%t][:split])
    avg_err[t] = e
    avg_train_err[t] = train_e
# Out:
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49393.74068360972, tolerance: 15852.413179833335
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47667.29078227139, tolerance: 15724.068879333336
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26175.766859059455, tolerance: 12741.6766465
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16686.675141420274, tolerance: 10807.227109333335
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48880.51325750569, tolerance: 15852.413179833335
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47147.82119365077, tolerance: 15724.068879333336
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25722.281764663043, tolerance: 12741.6766465
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16297.899104589102, tolerance: 10807.227109333335
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51609.95786530145, tolerance: 16561.744498584907
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52756.048332090286, tolerance: 16840.127258333334
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25613.903401242904, tolerance: 12909.577229559749
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25435.945958735923, tolerance: 12488.745785377358
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51801.6060482888, tolerance: 16561.744498584907
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52953.89276238512, tolerance: 16840.127258333334
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25776.665304124857, tolerance: 12909.577229559749
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25598.61652789343, tolerance: 12488.745785377358
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50219.75092291254, tolerance: 16561.744498584907
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51320.378024406644, tolerance: 16840.127258333334
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24435.462773771214, tolerance: 12909.577229559749
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24258.080707673165, tolerance: 12488.745785377358
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50230.503787775684, tolerance: 17033.51768333334
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48481.25013369876, tolerance: 17519.027885119052
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19723.34293457416, tolerance: 12517.165127976192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34059.199740561366, tolerance: 14831.062037946427
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51938.86712421363, tolerance: 17033.51768333334
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50183.66247681179, tolerance: 17519.027885119052
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21050.478143309076, tolerance: 12517.165127976192
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35615.760688062335, tolerance: 14831.062037946427
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49021.114368400915, tolerance: 16951.353489784946
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40249.598112022504, tolerance: 17281.42723655914
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15280.721027644235, tolerance: 12344.24972889785
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38604.43330889754, tolerance: 16248.870089784945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50240.89106913647, tolerance: 16951.353489784946
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41477.9235218339, tolerance: 17281.42723655914
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16167.622460075028, tolerance: 12344.24972889785
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39722.90386093172, tolerance: 16248.870089784945
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54606.79472292437, tolerance: 18508.523312179488
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38341.57407656239, tolerance: 17443.207951153847
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19307.57057546769, tolerance: 13377.119729615388
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40987.41212663772, tolerance: 17051.97619794872
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56273.4277695037, tolerance: 18508.523312179488
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39956.0231700688, tolerance: 17443.207951153847
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20593.26027625938, tolerance: 13377.119729615388
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42493.84431413302, tolerance: 17051.97619794872
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18803.945787792534, tolerance: 12102.796133333331
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63071.50831599982, tolerance: 20321.919305759806
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38812.00723296637, tolerance: 17491.665814583335
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24156.482762030995, tolerance: 14508.411235171568
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45408.82604704113, tolerance: 17832.326479289215
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18060.10993713209, tolerance: 12102.796133333331
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61984.32845971237, tolerance: 20321.919305759806
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37810.162309800406, tolerance: 17491.665814583335
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23298.615668151346, tolerance: 14508.411235171568
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44437.17613655317, tolerance: 17832.326479289215
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17656.463452497846, tolerance: 12102.796133333331
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61392.01467532769, tolerance: 20321.919305759806
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37265.23267327651, tolerance: 17491.665814583335
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22832.74868002477, tolerance: 14508.411235171568
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43908.364013346145, tolerance: 17832.326479289215
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20113.988689440914, tolerance: 12947.898891079814
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61589.894382939005, tolerance: 20868.21512992958
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30125.73014906708, tolerance: 16502.53801830986
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26160.84551069449, tolerance: 14943.054469953053
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42039.76733630801, tolerance: 18355.446094248833
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20834.443070365956, tolerance: 12947.898891079814
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62599.69351085846, tolerance: 20868.21512992958
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31001.943972302193, tolerance: 16502.53801830986
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26947.708278002785, tolerance: 14943.054469953053
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42978.997575213885, tolerance: 18355.446094248833
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48464.93207085013, tolerance: 14119.646999887389
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70047.53793088197, tolerance: 21715.303807995497
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50530.377627036934, tolerance: 14928.64899988739
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57026.662095613254, tolerance: 17210.75407736486
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60423.07401167801, tolerance: 18362.04540135135
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25458.635546926234, tolerance: 14119.646999887389
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64922.64809231747, tolerance: 21715.303807995497
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21437.61726955964, tolerance: 14928.64899988739
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35336.177600459254, tolerance: 17210.75407736486
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42497.94278932974, tolerance: 18362.04540135135
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25416.803713357214, tolerance: 14119.646999887389
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64867.69175661588, tolerance: 21715.303807995497
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21396.14050305263, tolerance: 14928.64899988739
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35289.63999427098, tolerance: 17210.75407736486
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42448.1034454457, tolerance: 18362.04540135135
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25660.77807258191, tolerance: 14119.646999887389
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65188.04435718537, tolerance: 21715.303807995497
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21638.27266416944, tolerance: 14928.64899988739
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35561.255894285954, tolerance: 17210.75407736486
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42738.69969648629, tolerance: 18362.04540135135
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24784.0153405527, tolerance: 14119.646999887389
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64035.249858755386, tolerance: 21715.303807995497
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20768.68589615973, tolerance: 14928.64899988739
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34584.722140090744, tolerance: 17210.75407736486
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41693.604616205965, tolerance: 18362.04540135135
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26932.554447436967, tolerance: 15246.911468722947
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 63687.89119972929, tolerance: 22547.21772943723
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39007.10240248857, tolerance: 18711.331795995673
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39084.725032759656, tolerance: 18422.602153571428
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29221.522529098245, tolerance: 15246.911468722947
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66749.92455353397, tolerance: 22547.21772943723
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14346.030877070893, tolerance: 13853.319258333331
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41622.32314964726, tolerance: 18711.331795995673
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41856.9817684514, tolerance: 18422.602153571428
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28690.49886683521, tolerance: 15246.911468722947
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66041.7170566692, tolerance: 22547.21772943723
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41016.52495641981, tolerance: 18711.331795995673
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41214.507351055756, tolerance: 18422.602153571428
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30069.580609216857, tolerance: 15834.825299895836
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65104.33435923973, tolerance: 22780.949674895834
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41962.78826602176, tolerance: 19074.736809895832
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42931.98781922864, tolerance: 19345.900346250004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29270.040610758908, tolerance: 15834.825299895836
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64046.97877140138, tolerance: 22780.949674895834
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41071.404654078186, tolerance: 19074.736809895832
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41956.09955130618, tolerance: 19345.900346250004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29365.260837616675, tolerance: 15834.825299895836
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64172.99247227688, tolerance: 22780.949674895834
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41177.629776510104, tolerance: 19074.736809895832
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42072.39636177811, tolerance: 19345.900346250004
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31367.432442149584, tolerance: 16549.066230020082
#   model = cd_fast.enet_coordinate_descent(
# ...
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41111.26980852499, tolerance: 19129.769900803214
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48045.22866675869, tolerance: 20840.78809668675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33426.53307567796, tolerance: 16549.066230020082
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66205.13877143298, tolerance: 22901.932897188755
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43608.22378166282, tolerance: 19129.769900803214
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50559.43506897452, tolerance: 20840.78809668675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33082.42978585258, tolerance: 16549.066230020082
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65808.80626824967, tolerance: 22901.932897188755
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42977.14090164603, tolerance: 19129.769900803214
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50167.63663731742, tolerance: 20840.78809668675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39161.78677918744, tolerance: 16549.066230020082
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51387.012512477406, tolerance: 22901.932897188755
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34230.4426592486, tolerance: 13262.874475502009
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43220.98413689321, tolerance: 19129.769900803214
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48298.35971410385, tolerance: 20840.78809668675
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36541.26901341813, tolerance: 17482.039431686047
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65432.28511612849, tolerance: 23054.162285949613
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46452.88930558247, tolerance: 20127.45922790698
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52264.32511043192, tolerance: 21572.50983401163
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42030.27416528893, tolerance: 19157.81549016854
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66123.99152999626, tolerance: 23875.888789794008
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54040.802616071756, tolerance: 22180.649690636703
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51952.48618121208, tolerance: 21916.09021226592
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44936.93594693989, tolerance: 20287.731782246377
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62452.1608057073, tolerance: 24270.097048913045
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57237.534482539326, tolerance: 23383.50796875
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51260.53947161761, tolerance: 22484.175073822462
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43841.18773656737, tolerance: 20287.731782246377
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61176.94429001419, tolerance: 24270.097048913045
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56064.70616703981, tolerance: 23383.50796875
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 50056.111643557495, tolerance: 22484.175073822462
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48753.30659135542, tolerance: 22407.312996052635
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58867.746731489824, tolerance: 25026.42775254386
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57684.47116987342, tolerance: 25579.34072491228
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\tbrid\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52616.276887055894, tolerance: 22996.25449991228
#   model = cd_fast.enet_coordinate_descent(
# <ipython-input-5-5bcc884282c3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['P_C_%i'%t] = 0.
# C:\Users\tbrid\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
# <ipython-input-5-5bcc884282c3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Error_%i'%t] = np.abs(df['P_C_%i'%t]-df['close'])

# %% [markdown]
# ## As you might have noticed, I created a new error column to save the absolute error values. Then I took the mean of the absolute error values, which I saved in a dictionary.
#
# ## Now it's time to plot and see what we got.

# %%
fig = plt.figure(facecolor=(1, 1, 1))
Range =df['high'][split:]-df['low'][split:]
plt.scatter(list(avg_train_err.keys()),list(avg_train_err.values()),label='train_error')
plt.legend(loc='best')
avgRange = np.average(Range)
plt.title(f'Avg Range = %1.2f'%avgRange)
print ('\nAverage Range of the data:',np.average(Range))
plt.savefig('../assets/lasso-error.png')
# Out:
# Average Range of the data: 61.986666666666665

# %% [markdown]
# ### I created a new Range value to hold the average daily trading range of the data. It is a metric that I would like to compare with when I am making a prediction. The logic behind this comparison is that if my prediction error is more than the day’s range then it is likely that it will not be useful.
#
# ### I might as well use the previous day’s High or Low as the prediction, which will turn out to be more accurate. Please note I have used the split value outside the loop. This implies that the average range of the day that you see here is relevant to the last iteration.
# ## What does this scatter plot tell you? Let me ask you a few questions.
#
# * Is the equation over-fitting?
# * The performance of the data improved remarkably as the train data set size increased. Does this mean if we give more data the error will reduce further?
# * Is there an inherent trend in the market, allowing us to make better predictions as the data set size increases?
# * Last but the best question How will we use these predictions to create a trading strategy?
# ### Q: Is the equation over-fitting?
# ### A: This was the first question I had asked. To know if your data is overfitting or not, the best way to test it would be to check the prediction error that the algorithm makes in the train and test data.
# ### To do this, we will have to add a small piece of code to the already written code.

# %%
fig = plt.figure(facecolor=(1, 1, 1))

Range =df['high'][split:]-df['low'][split:]
# ------------------------------------------------------------------------ added code below.
plt.scatter(list(avg_err.keys()),list(avg_err.values()), label='test_error')
# ---------------------------------------------------------------------------
plt.scatter(list(avg_train_err.keys()),list(avg_train_err.values()),label='train_error')
plt.legend(loc='best')
avR = np.average(Range)
plt.title(f'Avg Range = %1.2f'%avR)
print ('\nAverage Range of the Day:',np.average(Range))
plt.savefig('../assets/train-test-error.png')
# Out:
# Average Range of the Day: 61.986666666666665

# %% [markdown]
# ## If our algorithm is doing better in the test data compared to the train data, is this observation in itself a red flag.?There are a few reasons why our test data error could be better than the train data error:
#
# ## If the train data had greater volatility (Daily range) compared to the test set, then the prediction would also exhibit greater volatility.
# ### If there was an inherent trend in the market that helped the algo make better predictions.
# ### Now, let us check which of these cases is true. If the range of the test data was less than the train data, then the error should have decreased after passing more than 80% of the data as a train set, but it increases.

# %% [markdown]
# ## Q: Can the machine learning algorithm detect the inherent trend or market phase (bull/bear/sideways/breakout/panic)?
#
# ## Q: Can the database be trimmed in a way to train different algos for different situations
#
# ## A: The answer to both the questions is YES!
#
# ### We can divide the market into different regimes and then use these signals to trim the data and train different algorithms for these datasets. To achieve this, I choose to use an unsupervised machine learning algorithm.
#
# ### From here on, this Python machine learning tutorial will be dedicated to creating an algorithm that can detect the inherent trend in the market without explicitly training for it.

# %%
from pandas_datareader import data as web
from sklearn import mixture as mix
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=df[['open','high','low','close']]
df['open']=df['open'].shift(1)
df['high']=df['high'].shift(1)
df['low']=df['low'].shift(1)
df['close']=df['close'].shift(1)
df=df[['open','high','low','close']]
df=df.dropna()
# Out:
# <ipython-input-9-352752e9c380>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['open']=df['open'].shift(1)
# <ipython-input-9-352752e9c380>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['high']=df['high'].shift(1)
# <ipython-input-9-352752e9c380>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['low']=df['low'].shift(1)
# <ipython-input-9-352752e9c380>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['close']=df['close'].shift(1)

# %% [markdown]
# # Instantiate an unsupervised machine learning algorithm using the ‘Gaussian mixture’ model from sklearn.

# %%
unsup = mix.GaussianMixture(n_components=3, 
                            covariance_type="spherical", 
                            n_init=100, 
                            random_state=42)

# %%
unsup.fit(np.reshape(df,(-1,df.shape[1])))
regime = unsup.predict(np.reshape(df,(-1,df.shape[1])))

# %% [markdown]
# # Now let us calculate the returns of the day.

# %%
df['Return']= np.log(df['close']/df['close'].shift(1))

# %% [markdown]
# # Then, create a dataframe called Regimes which will have the OHLC and Return values along with the corresponding regime classification.

# %%
Regimes=pd.DataFrame(regime,columns=['Regime'],index=df.index)\
                     .join(df, how='inner')\
                          .assign(market_cu_return=df.Return.cumsum())\
                                 .reset_index(drop=False)\
                                             .rename(columns={'index':'Date'})

# %% [markdown]
# ## After this, let us create a list called ‘order’ that has the values corresponding to the regime classification, and then plot these values to see how well the algo has classified.

# %% [markdown]
# # The final regime differentiation would look like this:

# %%
order=[0,1,2]
fig = sns.FacetGrid(data=Regimes,hue='Regime',hue_order=order,aspect=2,height= 4)
fig.map(plt.scatter,'Date','market_cu_return', s=4).add_legend(labelcolor='white')
plt.tick_params(colors='white', grid_color='black')
plt.rcParams['text.color']='w'

plt.grid()
plt.savefig('../assets/lasso.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### This graph looks pretty good to me. Without actually looking at the factors based on which the classification was done, we can conclude a few things just by looking at the chart.
#
# 1. The blue zone is the low volatility or the sideways zone
# 2. The orange zone is high volatility zone or panic zone.
# 3. The purple zone is a breakout up/down zone.
# 4. The red zone: high Mean, high covariance zone.
# 5. The purple zone mid mean low covariance i really have no clue besided looks toppy and rangey
# * Use the code below to print the relevant data for each regime

# %%
for i in order:
    print('Mean for regime %i: '%i,unsup.means_[i][0])
    print('Co-Variancefor regime %i: '%i,(unsup.covariances_[i]))
    
# The output would look like this:
# Out:
# Mean for regime 0:  61129.59908195839
# Co-Variancefor regime 0:  23670.960840867592
# Mean for regime 1:  61581.337756052104
# Co-Variancefor regime 1:  25375.771356748177
# Mean for regime 2:  62185.61386646698
# Co-Variancefor regime 2:  20320.327363418175

# %% [markdown]
# ### The data can be inferred as follows:
# 0. Regime 0: high mean and low covariance.
# 1. Regime 1: low mean and high covariance.
# 2. Regime 2: mid range mean and low covariance.
# 3. Regime 3: high mean and low covariance.
# 4. Regime 4: mid mean low covariance.
